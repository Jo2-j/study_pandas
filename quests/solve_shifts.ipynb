# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import matplotlib as mpl 
# 한글 폰트 설정 (NanumGothic) 
mpl.rcParams['font.family'] = 'NanumGothic'
import pandas as pd

# %%
fdrSNP = fdr.DataReader('S&P500', '2024-11-01')


# fdrSNP
fdrSNP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2024-11-01 to 2024-12-23
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       36 non-null     float64
#  1   High       36 non-null     float64
#  2   Low        36 non-null     float64
#  3   Close      36 non-null     float64
#  4   Volume     36 non-null     int64
#  5   Adj Close  36 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 2.0 KB

# %%
fdrSNP['Adj Close'].mean(), fdrSNP['Adj Close'].median()
# Out:
# (5971.954440646701, 5986.375)

# %%
# 1. 기본 통계 계산

# # conditions = fdrSNP['Adj Close'] > fdrSNP['Adj Close'].mean()
# # fdrSNP['Adj Close'].apply(conditions)
# conditions T, False 로만 나옴

# 방법 1: 조건을 직접 인덱싱에 사용
conditions = fdrSNP['Adj Close'] > fdrSNP['Adj Close'].mean()
above_mean_values = fdrSNP['Adj Close'][conditions]

# # 방법 2: loc 사용
# above_mean_values = fdrSNP.loc[conditions, 'Adj Close']

# # 방법 3: boolean indexing
# above_mean_values = fdrSNP['Adj Close'][fdrSNP['Adj Close'] > fdrSNP['Adj Close'].mean()]
above_mean_values
# Out:
# 2024-11-07    5973.100098
# 2024-11-08    5995.540039
# 2024-11-11    6001.350098
# 2024-11-12    5983.990234
# 2024-11-13    5985.379883
# 2024-11-25    5987.370117
# 2024-11-26    6021.629883
# 2024-11-27    5998.740234
# 2024-11-29    6032.379883
# 2024-12-02    6047.149902
# 2024-12-03    6049.879883
# 2024-12-04    6086.490234
# 2024-12-05    6075.109863
# 2024-12-06    6090.270020
# 2024-12-09    6052.850098
# 2024-12-10    6034.910156
# 2024-12-11    6084.189941
# 2024-12-12    6051.250000
# 2024-12-13    6051.089844
# 2024-12-16    6074.080078
# 2024-12-17    6050.609863
# 2024-12-23    5974.069824
# Name: Adj Close, dtype: float64

# %%
# 2. 이동 평균(rolling) 계산


# 7일 이동 평균(rolling mean)을 계산하여 새로운 열로 추가하세요.
# 7일 이동 평균과 실제 종가의 차이를 계산하여 열로 추가하세요.

fdrSNP['rolling7'] = fdrSNP['Adj Close'].rolling(window=7).mean()
# fdrSNP

fdrSNP = fdrSNP['Adj Close'].rolling(window=7).mean()
# Out:
#                    Open         High          Low        Close      Volume  \
# 2024-11-01  5723.220215  5772.520020  5723.220215  5728.799805  3796450000
# 2024-11-04  5725.149902  5741.430176  5696.509766  5712.689941  3602060000
# 2024-11-05  5722.430176  5783.439941  5722.100098  5782.759766  3768310000
# 2024-11-06  5864.890137  5936.140137  5864.890137  5929.040039  6329530000
# 2024-11-07  5947.209961  5983.839844  5947.209961  5973.100098  4925740000
# 2024-11-08  5976.759766  6012.450195  5976.759766  5995.540039  4666740000
# 2024-11-11  6008.859863  6017.310059  5986.689941  6001.350098  4333000000
# 2024-11-12  6003.600098  6009.919922  5960.080078  5983.990234  4243400000
# 2024-11-13  5985.750000  6008.189941  5965.910156  5985.379883  4220180000
# 2024-11-14  5989.680176  5993.879883  5942.279785  5949.169922  4184570000
# 2024-11-15  5912.790039  5915.319824  5853.009766  5870.620117  4590960000
# ...
