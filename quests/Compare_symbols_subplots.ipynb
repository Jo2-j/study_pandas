# %% [markdown]
# 코스피와 관심종목 비교 Charts 작성
# - figuresize = (4,1)
# - 비교 컬럼은 자유

# %%
# 코스피 정보 출력

import matplotlib.pyplot as plt

import matplotlib as mpl 
# 한글 폰트 설정 (NanumGothic) 
mpl.rcParams['font.family'] = 'NanumGothic'

import FinanceDataReader as fdr

kospi = fdr.DataReader('KS11', '2021-08-10')
krafton = fdr.DataReader('259960', '2021-08-10')

# %%
# kospi.info()
# krafton.info()

# %%
# kospi.describe()

# %%
# krafton.describe()

# %%
plt.plot(kospi['Change'], label='코스피 변동률')
plt.plot(krafton['Change'], label='크래프톤 변동률')


plt.title('크래프톤 상장 후 코스피와의 비교')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()

plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumGothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, axes = plt.subplots(4, 1, figsize=(10, 10))  # figsize로 전체 그래프 크기 조절



# 첫 번째 subplot - 코스피 변동률
axes[0].plot(kospi['Change'], label='코스피 변동률')
axes[0].legend()

# 두 번째 subplot - 크래프톤 변동률
axes[1].plot(krafton['Change'], label='크래프톤 변동률')
axes[1].legend()

# 세 번째 subplot - 두 변동률 차이
axes[2].plot(kospi['Change'] - krafton['Change'], label='변동률 차이')
axes[2].legend()

# 네 번째 subplot - 두 변동률 비교
axes[3].plot(kospi['Change'], label='코스피 변동률')
axes[3].plot(krafton['Change'], label='크래프톤 변동률')
axes[3].legend()



plt.tight_layout()  # subplot 간 간격 자동 조절
plt.savefig('kospiAndKrafton')
plt.show()
# Out:
# /tmp/ipykernel_12271/1765717885.py:24: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumGothic.
#   plt.tight_layout()  # subplot 간 간격 자동 조절
# /tmp/ipykernel_12271/1765717885.py:25: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) NanumGothic.
#   plt.savefig('kospiAndKrafton')

# %%
# # plt.figure(figsize=(10, 5)) # 10인치 x 6인치
# plt.figure(figsize=(4, 1), dpi=1000) # Pixels per inch


# plt.plot(kospi['Change'], label='코스피 변동률')
# plt.plot(krafton['Change'], label='크래프톤 변동률')
