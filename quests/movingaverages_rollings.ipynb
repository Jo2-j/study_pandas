# %% [markdown]
# - 5, 20, 60, 120 이동평균 작성
# - charts (4/4분면)
# - 각 이동평균별 최고치와 최저치 출력

# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import matplotlib as mpl 
# 한글 폰트 설정 (NanumGothic) 
mpl.rcParams['font.family'] = 'NanumGothic'

# %%
fdrSNP = fdr.DataReader('S&P500', '2021-12-23')

#fdrSNP

fdrSNP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 753 entries, 2021-12-23 to 2024-12-20
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       753 non-null    float64
#  1   High       753 non-null    float64
#  2   Low        753 non-null    float64
#  3   Close      753 non-null    float64
#  4   Volume     753 non-null    int64
#  5   Adj Close  753 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 41.2 KB

# %%
fdrSNP['rolling5'] = fdrSNP['Adj Close'].rolling(window=5).mean()
fdrSNP['rolling20'] = fdrSNP['Adj Close'].rolling(window=20).mean()
fdrSNP['rolling60'] = fdrSNP['Adj Close'].rolling(window=60).mean()
fdrSNP['rolling120'] = fdrSNP['Adj Close'].rolling(window=120).mean()

# %%
plt.plot(fdrSNP['rolling5'])
plt.show()

# %%
plt.plot(fdrSNP['rolling20'])
plt.show()

# %%
plt.plot(fdrSNP['rolling60'])
plt.show()

# %%
plt.plot(fdrSNP['rolling120'])
plt.show()
