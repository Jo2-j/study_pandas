# %% [markdown]
# - 5, 20, 60, 120 이동평균 작성
# - charts (4/4분면)
# - 각 이동평균별 최고치와 최저치 출력

# %%
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import matplotlib as mpl 
# 한글 폰트 설정 (NanumGothic) 
mpl.rcParams['font.family'] = 'NanumGothic'

# %%
fdrSNP = fdr.DataReader('S&P500', '2021-12-23')

#fdrSNP
fdrSNP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 753 entries, 2021-12-23 to 2024-12-20
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       753 non-null    float64
#  1   High       753 non-null    float64
#  2   Low        753 non-null    float64
#  3   Close      753 non-null    float64
#  4   Volume     753 non-null    int64
#  5   Adj Close  753 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 41.2 KB

# %%
fdrSNP['rolling5'] = fdrSNP['Adj Close'].rolling(window=5).mean()
fdrSNP['rolling20'] = fdrSNP['Adj Close'].rolling(window=20).mean()
fdrSNP['rolling60'] = fdrSNP['Adj Close'].rolling(window=60).mean()
fdrSNP['rolling120'] = fdrSNP['Adj Close'].rolling(window=120).mean()

# %%
plt.plot(fdrSNP['rolling5'])
plt.tight_layout()
plt.title('5 Days EMA')
plt.show()

# %%
plt.plot(fdrSNP['rolling20'])
plt.tight_layout()
plt.title('20 Days EMA')
plt.show()

# %%
plt.plot(fdrSNP['rolling60'])
plt.tight_layout()
plt.title('60 Days EMA')
plt.show()

# %%
plt.plot(fdrSNP['rolling120'])
plt.tight_layout()
plt.title('120 Days EMA')
plt.show()

# %%
# fig, axes =plt.subplots(1,4)
# plt.figure(figsize=(100, 50), dpi=100) # Pixels per inch

# axes[0].plot(fdrSNP['rolling5'])
# axes[0].set_title('5 Days EMA')
# axes[0].set_xlabel('Date')
# axes[0].set_ylabel('Price / $')

# axes[1].plot(fdrSNP['rolling20'])
# axes[1].set_title('20 Days EMA')
# axes[1].set_xlabel('Date')
# axes[1].set_ylabel('Price / $')

# axes[2].plot(fdrSNP['rolling60'])
# axes[2].set_title('60 Days EMA')
# axes[2].set_xlabel('Date')
# axes[2].set_ylabel('Price / $')

# axes[3].plot(fdrSNP['rolling120'])
# axes[3].set_title('120 Days EMA')
# axes[3].set_xlabel('Date')
# axes[3].set_ylabel('Price / $')

# plt.tight_layout()
# plt.show()

# %%
# 그래프 크기와 레이아웃 설정
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('S&P500 이동평균선', fontsize=16, y=1.02)

# 5일 이동평균
axes[0,0].plot(fdrSNP['rolling5'], color='blue')
axes[0,0].set_title('5일 이동평균')
axes[0,0].set_xlabel('날짜')
axes[0,0].set_ylabel('가격($)')
axes[0,0].tick_params(axis='x', rotation=45)
axes[0,0].grid(True)

# 20일 이동평균
axes[0,1].plot(fdrSNP['rolling20'], color='red')
axes[0,1].set_title('20일 이동평균')
axes[0,1].set_xlabel('날짜')
axes[0,1].set_ylabel('가격($)')
axes[0,1].tick_params(axis='x', rotation=45)
axes[0,1].grid(True)

# 60일 이동평균
axes[1,0].plot(fdrSNP['rolling60'], color='green')
axes[1,0].set_title('60일 이동평균')
axes[1,0].set_xlabel('날짜')
axes[1,0].set_ylabel('가격($)')
axes[1,0].tick_params(axis='x', rotation=45)
axes[1,0].grid(True)

# 120일 이동평균
axes[1,1].plot(fdrSNP['rolling120'], color='purple')
axes[1,1].set_title('120일 이동평균')
axes[1,1].set_xlabel('날짜')
axes[1,1].set_ylabel('가격($)')
axes[1,1].tick_params(axis='x', rotation=45)
axes[1,1].grid(True)

# 그래프 간 간격 조정
plt.tight_layout()
plt.show()

# 각 이동평균선의 최고치와 최저치 출력
print("\n각 이동평균선의 최고치와 최저치:")
for period in [5, 20, 60, 120]:
    col = f'rolling{period}'
    max_val = fdrSNP[col].max()
    min_val = fdrSNP[col].min()
    print(f"\n{period}일 이동평균:")
    print(f"최고치: ${max_val:.2f}")
    print(f"최저치: ${min_val:.2f}")
# Out:
# 각 이동평균선의 최고치와 최저치:
#
# 5일 이동평균:
# 최고치: $6070.92
# 최저치: $3606.25
#
# 20일 이동평균:
# 최고치: $6027.01
# 최저치: $3668.38
#
# 60일 이동평균:
# 최고치: $5895.67
# 최저치: $3821.02
#
# 120일 이동평균:
# 최고치: $5716.98
# 최저치: $3902.25
