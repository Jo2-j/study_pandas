# %%
import pandas as pd

# %% [markdown]
# ## load from xlsx

# %%
df_xlsx = pd.read_excel(io='../datasets/02.code.xlsx')
df_xlsx
# Out:
#       Unnamed: 0       cd      nm   gb
# 0              0  A060310      3S  701
# 1              1  A095570  AJ네트웍스  701
# 2              2  A006840   AK홀딩스  701
# 3              3  A054620  APS홀딩스  701
# 4              4  A265520   AP시스템  701
# ...          ...      ...     ...  ...
# 2561        2561  A189980  흥국에프엔비  701
# 2562        2562  A000540    흥국화재  701
# 2563        2563  A003280    흥아해운  701
# 2564        2564  A037440      희림  701
# 2565        2565  A238490      힘스  701
#
# [2566 rows x 4 columns]

# %%
df_xlsx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2566 entries, 0 to 2565
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2566 non-null   int64
#  1   cd          2566 non-null   object
#  2   nm          2566 non-null   object
#  3   gb          2566 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 80.3+ KB

# %%
df_xlsx.describe()
# Out:
#         Unnamed: 0      gb
# count  2566.000000  2566.0
# mean   1282.500000   701.0
# std     740.884719     0.0
# min       0.000000   701.0
# 25%     641.250000   701.0
# 50%    1282.500000   701.0
# 75%    1923.750000   701.0
# max    2565.000000   701.0

# %%
df_html = pd.read_html('https://comp.fnguide.com/SVO2/ASP/SVD_main.asp?pGB=1&gicode=A005930&cID=&MenuYn=Y&ReportGB=&NewMenuID=11&stkGb=&strResearchYN=')
df_html
# Out:
# [                     0                              1              2  \
#  0             종가/ 전일대비                   55,600/ -500            거래량
#  1         52주.최고가/ 최저가                 87,800/ 49,900       거래대금(억원)
#  2  수익률(1M/ 3M/ 6M/ 1Y)  +3.93/ -13.66/ -30.15/ -24.15       외국인 보유비중
#  3      시가총액(상장예정포함,억원)                        3702253         베타(1년)
#  4         시가총액(보통주,억원)                        3319199            액면가
#  5                  NaN                            NaN            NaN
#  6      발행주식수(보통주/ 우선주)     5,969,782,550/ 822,886,700  유동주식수/비율(보통주)
#
#                         3
#  0               15277277
#  1                   8536
#  2                  50.91
#  3                1.22766
#  4                    100
#  5                    NaN
#  6  4,544,753,599 / 76.13  ,
#    잠정실적발표예정일  예상실적(영업이익, 억원)  3개월전예상실적대비(%)  전년동기대비(%)
#  0        미정          358086         -16.04     445.28,
#            운용사명      보유수량     시가평가액  상장주식수내비중  운용사내비중
# ...

# %% [markdown]
# ## load from CSV

# %%
pd.read_csv('../datasets/02.magic.csv')
# Out:
#      code    name    ROIC  EV/EBITDA
# 0  187660  에디엠코리아  2110.7       0.02
# 1  227420   도부마스크   394.7       1.23
# 2  225220    제놀루션   333.9       2.40
# 3    1880    DL건설   344.8       3.15

# %% [markdown]
# ## load from html

# %%
import requests

uri = 'https://finance.naver.com/'
requests.get(uri)

response = requests.get(uri)

# %%
df_read_html = pd.read_html(io=response.text, encoding='utf-8')
# Out:
# /tmp/ipykernel_579/3376660858.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_read_html = pd.read_html(io=response.text, encoding='utf-8')

# %%
type(df_read_html), len(df_read_html)
# Out:
# (list, 12)

# %%
df_read_html[0]
# Out:
#                   종목명   현재가    전일대비      등락률
# 0                대원전선  3425  상승 215   +6.70%
# 1              오리엔트정공  6350  하락 350   -5.22%
# 2    KODEX 200선물인버스2X  2470   상승 30   +1.23%
# 3               SG글로벌  3960  상승 695  +21.29%
# 4               넥스트아이   606   상승 10   +1.68%
# 5               쓰리빌리언  6750  상승 750  +12.50%
# 6             오리엔트바이오  1211   상승 51   +4.40%
# 7   KODEX 코스닥150선물인버스  4090   상승 40   +0.99%
# 8    KODEX 코스닥150레버리지  6955  하락 125   -1.77%
# 9           코오롱모빌리티그룹  2980  상승 455  +18.02%
# 10          이스트아시아홀딩스    63    하락 6   -8.70%
# 11          한국ANKOR유전   342   상승 16   +4.91%
# 12                유비온  1336   상승 64   +5.03%
# 13               삼부토건   993   상승 26   +2.69%
# 14           에이비프로바이오   486   하락 35   -6.72%

# %%
df_read_html[1]
# Out:
#            종목명    현재가       전일대비      등락률
# 0       한국정밀기계   2925    상한가 675  +30.00%
# 1       아이윈플러스    963    상한가 222  +29.96%
# 2        인벤티지랩  17350  상한가 4,000  +29.96%
# 3        GH신소재   3450    상한가 795  +29.94%
# 4      뱅크웨어글로벌   9420  상한가 2,170  +29.93%
# 5      CJ씨푸드1우  23650  상한가 5,420  +29.73%
# 6        효성오앤비   9370   상승 1,890  +25.27%
# 7        대원전선우   4745     상승 925  +24.21%
# 8      자람테크놀로지  48550   상승 8,550  +21.38%
# 9        SG글로벌   3960     상승 695  +21.29%
# 10   코오롱모빌리티그룹   2980     상승 455  +18.02%
# 11       에이직랜드  31300   상승 4,300  +15.93%
# 12  코오롱모빌리티그룹우   4560     상승 615  +15.59%
# 13         나이벡  17920   상승 2,260  +14.43%
# 14   엔브이에이치코리아   2800     상승 345  +14.05%

# %% [markdown]
# ## save to file

# %%
df_up_cds = df_read_html[1]
df_up_cds
# Out:
#            종목명    현재가       전일대비      등락률
# 0       한국정밀기계   2925    상한가 675  +30.00%
# 1       아이윈플러스    963    상한가 222  +29.96%
# 2        인벤티지랩  17350  상한가 4,000  +29.96%
# 3        GH신소재   3450    상한가 795  +29.94%
# 4      뱅크웨어글로벌   9420  상한가 2,170  +29.93%
# 5      CJ씨푸드1우  23650  상한가 5,420  +29.73%
# 6        효성오앤비   9370   상승 1,890  +25.27%
# 7        대원전선우   4745     상승 925  +24.21%
# 8      자람테크놀로지  48550   상승 8,550  +21.38%
# 9        SG글로벌   3960     상승 695  +21.29%
# 10   코오롱모빌리티그룹   2980     상승 455  +18.02%
# 11       에이직랜드  31300   상승 4,300  +15.93%
# 12  코오롱모빌리티그룹우   4560     상승 615  +15.59%
# 13         나이벡  17920   상승 2,260  +14.43%
# 14   엔브이에이치코리아   2800     상승 345  +14.05%

# %%
df_up_cds.to_csv('../datasets/02.save_html.csv')

# %%
type(df_up_cds), len(df_up_cds)
# Out:
# (pandas.core.frame.DataFrame, 15)

# %%
file_path = '../datasets/test.xlsx'
pd.read_excel(file_path, header=2)
# Out:
#          회사명             수수료\n부과기준        기준일자  거래금액   구분        오프라인     HTS  \
# 0     유진투자증권  /img/sub/ico_xls.gif  2012/10/08  50만원  변경전         NaN     NaN
# 1     유진투자증권  /img/sub/ico_xls.gif  2020/06/17  50만원  변경후  2500.00000   900.0
# 2     유진투자증권  /img/sub/ico_xls.gif  2020/06/17  50만원  변경율         NaN     NaN
# 3       SK증권  /img/sub/ico_xls.gif  2011/11/18  50만원  변경전  2500.00000  1750.0
# 4       SK증권  /img/sub/ico_xls.gif  2015/06/01  50만원  변경후  2500.00000  1750.0
# ..       ...                   ...         ...   ...  ...         ...     ...
# 91  비엔피파리바증권  /img/sub/ico_pdf.gif  2020/02/03  50만원  변경율    -0.23077     NaN
# 92      토스증권  /img/sub/ico_pdf.gif  2021/01/21  50만원  변경후         NaN     NaN
# 93  비엔케이투자증권  /img/sub/ico_pdf.gif  2016/12/05  50만원  변경전         NaN     NaN
# 94  비엔케이투자증권  /img/sub/ico_pdf.gif  2020/08/24  50만원  변경후  2246.00000  1496.0
# 95  비엔케이투자증권  /img/sub/ico_pdf.gif  2020/08/24  50만원  변경율         NaN     NaN
#
# ...

# %%
findPostInterates = pd.read_excel(file_path, header=2)
findPostInterates
# Out:
#          회사명             수수료\n부과기준        기준일자  거래금액   구분        오프라인     HTS  \
# 0     유진투자증권  /img/sub/ico_xls.gif  2012/10/08  50만원  변경전         NaN     NaN
# 1     유진투자증권  /img/sub/ico_xls.gif  2020/06/17  50만원  변경후  2500.00000   900.0
# 2     유진투자증권  /img/sub/ico_xls.gif  2020/06/17  50만원  변경율         NaN     NaN
# 3       SK증권  /img/sub/ico_xls.gif  2011/11/18  50만원  변경전  2500.00000  1750.0
# 4       SK증권  /img/sub/ico_xls.gif  2015/06/01  50만원  변경후  2500.00000  1750.0
# ..       ...                   ...         ...   ...  ...         ...     ...
# 91  비엔피파리바증권  /img/sub/ico_pdf.gif  2020/02/03  50만원  변경율    -0.23077     NaN
# 92      토스증권  /img/sub/ico_pdf.gif  2021/01/21  50만원  변경후         NaN     NaN
# 93  비엔케이투자증권  /img/sub/ico_pdf.gif  2016/12/05  50만원  변경전         NaN     NaN
# 94  비엔케이투자증권  /img/sub/ico_pdf.gif  2020/08/24  50만원  변경후  2246.00000  1496.0
# 95  비엔케이투자증권  /img/sub/ico_pdf.gif  2020/08/24  50만원  변경율         NaN     NaN
#
# ...

# %%
changedInterates = findPostInterates[findPostInterates['구분'] == '변경후']
changedInterates
# Out:
#           회사명              수수료\n부과기준        기준일자  거래금액   구분    오프라인     HTS  \
# 1      유진투자증권   /img/sub/ico_xls.gif  2020/06/17  50만원  변경후  2500.0   900.0
# 4        SK증권   /img/sub/ico_xls.gif  2015/06/01  50만원  변경후  2500.0  1750.0
# 7       유안타증권   /img/sub/ico_pdf.gif  2021/01/04  50만원  변경후  2500.0  1750.0
# 10     신한투자증권   /img/sub/ico_pdf.gif  2015/04/01  50만원  변경후     NaN     NaN
# 13       유화증권   /img/sub/ico_pdf.gif  2012/05/02  50만원  변경후  2490.0   390.0
# 16     미래에셋증권   /img/sub/ico_pdf.gif  2017/01/02  50만원  변경후  2450.0   700.0
# 18      상상인증권   /img/sub/ico_pdf.gif  2020/04/23  50만원  변경후  2450.0   700.0
# 20       대신증권   /img/sub/ico_pdf.gif  2021/01/01  50만원  변경후  2486.0  1536.0
# 23       교보증권   /img/sub/ico_pdf.gif  2021/09/01  50만원  변경후  2490.0  1240.0
# 25     NH투자증권   /img/sub/ico_pdf.gif  2020/06/10  50만원  변경후  2486.0  1571.0
# 27       한양증권   /img/sub/ico_hwp.gif  2012/10/12  50만원  변경후  2487.0  2236.0
# ...

# %%
changedInterates['증권사 개설 계좌'] = changedInterates['HTS'] + changedInterates['스마트폰']
changedInterates
# Out:
# /tmp/ipykernel_579/1000570393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   changedInterates['증권사 개설 계좌'] = changedInterates['HTS'] + changedInterates['스마트폰']
#           회사명              수수료\n부과기준        기준일자  거래금액   구분    오프라인     HTS  \
# 1      유진투자증권   /img/sub/ico_xls.gif  2020/06/17  50만원  변경후  2500.0   900.0
# 4        SK증권   /img/sub/ico_xls.gif  2015/06/01  50만원  변경후  2500.0  1750.0
# 7       유안타증권   /img/sub/ico_pdf.gif  2021/01/04  50만원  변경후  2500.0  1750.0
# 10     신한투자증권   /img/sub/ico_pdf.gif  2015/04/01  50만원  변경후     NaN     NaN
# 13       유화증권   /img/sub/ico_pdf.gif  2012/05/02  50만원  변경후  2490.0   390.0
# 16     미래에셋증권   /img/sub/ico_pdf.gif  2017/01/02  50만원  변경후  2450.0   700.0
# ...
